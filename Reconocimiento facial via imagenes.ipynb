# %%
# Instalaremos la libreria FER() library to para realizar el reconocimiento facial
# Esta instalación corregira la dependencias faltantes.

# %%
pip install fer
# Out:
# ...
#
# ...

# %%
# Se ejecuta el codigo

# %%
from fer import FER
import matplotlib.pyplot as plt 
# %matplotlib inline

# Se pueden probar desde la i1 hasta la i7.
imagen_ejemplo = plt.imread("Images/i7.jpg")
emo_det = FER(mtcnn=True)
# Captura todas las emociones en la imagen
cap_emo = emo_det.detect_emotions(test_image)
# Imprime todas las emociones capturadas de la imagen
print(cap_emo)
plt.imshow(test_image)
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image)
print(dominant_emotion, emotion_score)
# Out:
# [{'box': [247, 341, 410, 557], 'emotions': {'angry': 0.1, 'disgust': 0.01, 'fear': 0.11, 'happy': 0.0, 'sad': 0.66, 'surprise': 0.0, 'neutral': 0.11}}]
# sad 0.66
